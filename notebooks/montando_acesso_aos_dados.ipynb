# %%
dbutils.fs.mkdirs("/mnt/dados")

# %%
display(dbutils.fs.ls("/mnt/dados"))

# %% [markdown]
# 1. Criar a Credential (Service Principal do ADLS)
#
# Scala

# %% [markdown]
# Python

# %%
configs = {"fs.azure.account.auth.type": "OAuth",
          "fs.azure.account.oauth.provider.type": "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider",
          "fs.azure.account.oauth2.client.id": "aa26ccad-21ed-4a13-bfec-3664b2821d18",
          "fs.azure.account.oauth2.client.secret": "CuC8Q~KEt-LeJo4~Ht5LZZD~zsrkw_l5gDtWDcsm",
          "fs.azure.account.oauth2.client.endpoint": "https://login.microsoftonline.com/061b2429-0eaa-40a5-b0f6-1622c51a0ae1/oauth2/token"}

# Optionally, you can add <directory-name> to the source URI of your mount point.
dbutils.fs.mount(source = "abfss://imoveis@datalakemho.dfs.core.windows.net/",
  mount_point = "/mnt/dados", extra_configs = configs)

# %%
# %python
dbutils.fs.ls("/mnt/dados")
